# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Fir

# %%
GALLONNS_PER_TICK = 0.075

df = pd.read_csv('nightdata/oak/primary-flow_ticklist.1729947612.csv')
df['timestamp'] = pd.to_datetime(df.timestamp)
df['gpm'] = [x*60*GALLONNS_PER_TICK for x in list(df.frequency)]
display(df)

plt.plot(df.timestamp, df.gpm)
plt.ylabel(f'GPM (assuming {GALLONNS_PER_TICK} gallons per tick)')
plt.tight_layout()
plt.show()
# Out:
#                          timestamp  frequency  tick_delta_ms  \
# 0    2024-10-26 13:15:09.451149824   1.503760              0
# 1    2024-10-26 13:15:10.116149760   1.447178            665
# 2    2024-10-26 13:15:10.807149824   1.470588           1356
# 3    2024-10-26 13:15:11.487149824   1.455604           2036
# 4    2024-10-26 13:15:12.174149888   1.468429           2723
# ...                            ...        ...            ...
# 1047 2024-10-26 13:31:40.248067584   0.633714          11002
# 1048 2024-10-26 13:31:41.826067712   0.632111          12580
# 1049 2024-10-26 13:31:43.408067584   0.632111          14162
# 1050 2024-10-26 13:31:44.988744192   0.632911              0
# 1051 2024-10-26 13:31:46.568744192   0.632911           1580
#
#       pico_time_delay_ns       gpm
# 0           1.202532e+17  6.766918
# 1           1.202532e+17  6.512300
# 2           1.202532e+17  6.617647
# 3           1.202532e+17  6.550218
# 4           1.202532e+17  6.607930
# ...                  ...       ...
# 1047        1.202532e+17  2.851711
# 1048        1.202532e+17  2.844500
# 1049        1.202532e+17  2.844500
# 1050        1.202532e+17  2.848101
# 1051        1.202532e+17  2.848101
#
# [1052 rows x 5 columns]

# %% [markdown]
# # Oak

# %%
GALLONNS_PER_TICK = 1

df = pd.read_csv('nightdata/oak/primary-flow_ticklist.1729911093.csv')
df['timestamp'] = pd.to_datetime(df.timestamp)
df['gpm'] = [x*60*GALLONNS_PER_TICK for x in list(df.frequency)]
plt.plot(df.timestamp, df.gpm)
plt.ylabel(f'GPM (assuming {GALLONNS_PER_TICK} gallons per tick)')
plt.ylim([60,100])
plt.tight_layout()
plt.show()
