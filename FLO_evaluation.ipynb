# %%
import pendulum
from flo_eval import FloEval

# %%
house_alias = 'oak'
timezone = 'America/New_York'
YEAR, MONTH, DAY, HOUR = 2025, 2, 11, 12

# %%
start_ms = pendulum.datetime(YEAR, MONTH, DAY, HOUR, tz=timezone).timestamp() * 1000
f = FloEval(house_alias, start_ms, timezone)
f.plot()
# Out:
# Found FLO at 2025-02-12 11:55:33.249000-05:00
# 2025-02-11 12:00:00-05:00
# 2025-02-11 13:00:00-05:00
# 2025-02-11 14:00:00-05:00
# 2025-02-11 15:00:00-05:00
# 2025-02-11 16:00:00-05:00
# 2025-02-11 17:00:00-05:00
# 2025-02-11 18:00:00-05:00
# 2025-02-11 19:00:00-05:00
# 2025-02-11 20:00:00-05:00
# 2025-02-11 21:00:00-05:00
# 2025-02-11 22:00:00-05:00
# 2025-02-11 23:00:00-05:00
# 2025-02-12 00:00:00-05:00
# 2025-02-12 01:00:00-05:00
# 2025-02-12 02:00:00-05:00
# 2025-02-12 03:00:00-05:00
# 2025-02-12 04:00:00-05:00
# 2025-02-12 05:00:00-05:00
# 2025-02-12 06:00:00-05:00
# 2025-02-12 07:00:00-05:00
# 2025-02-12 08:00:00-05:00
# 2025-02-12 09:00:00-05:00
# 2025-02-12 10:00:00-05:00
# 2025-02-12 11:00:00-05:00
# 2025-02-12 12:00:00-05:00
